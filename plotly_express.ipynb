# %% [markdown]
# Галерея plotly-express
# https://plotly.com/python/plotly-express/
# https://plotly.com/python/px-arguments/
# functions docs
# https://plotly.github.io/plotly.py-docs/generated/plotly.express.html

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots

# %% [markdown]
# Чтобы отключить плавающую панель инструментов в Plotly (modebar)

# %%
import plotly.io as pio
pio.renderers['jupyterlab'].config['displayModeBar'] = False

# %% [markdown]
# plotly Chart Studio
# https://plotly.com/python/getting-started-with-chart-studio/

# %%
import plotly.express as px
 
import chart_studio
 
import chart_studio.plotly as py
chart_studio.tools.set_credentials_file(username="your username", api_key="your api key")
# from jupyter to chart studio
py.plot(fig, filename = "plot name", auto_open = True)
# from chart studio to jupyter
fig = py.get_figure("https://plotly.com/~PlotBot/5")

# %% [markdown]
# Plotly for pandas backend

# %%
pd.options.plotting.backend = "plotly"

# %%
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %% [markdown]
# сохранить картинку из figure plotly в файл
# можно сохранять в разных форматах
# png, jpeg, svg, pdf

# %%
# !pip install kaleido

# %%
# from plotly.io import write_image
import plotly.express as ex
fig = ex.scatter(x=[1,2,3], y=[5,6,7], title='my_title', height=500, width=700)
fig.write_image('my_fig.pdf', engine='kaleido')

# %% [markdown]
# Посмотреть цвета

# %%
# непрерывные
px.colors.sequential.swatches()

# %% [markdown]
# Для линий и разных категорий баров будут браться цвета из qualitative
# слева на права по картинке

# %%
# дискретный
px.colors.qualitative.swatches()

# %% [markdown]
# Установить настройки по умолчанию для всех цветов

# %%
px.colors.sequential
# Out:
# ['rgb(243, 224, 247)',
#  'rgb(228, 199, 241)',
#  'rgb(209, 175, 232)',
#  'rgb(185, 152, 221)',
#  'rgb(159, 130, 206)',
#  'rgb(130, 109, 186)',
#  'rgb(99, 88, 159)']

# %% [markdown]
# Коды цветов Plotly можно посмотреть, например, здесь
# https://zzahir1978.github.io/projects/PlotlyDiscreteColorCodes.html
# Выбрать цвет из набора можно тут
# Нажимаем на любой набор, в буфер копируется список всех кодов палитры,
# далее можно самому выбрать нужный код из списка
# https://observablehq.com/@d3/color-schemes?collection=@d3/d3-scale-chromatic

# %% [markdown]
# Если нужно изменить на графике что-то, то
# нужно понять это `layout` и `data`
# и использовать
# `fig.update_traces` или `fig.update_layout` соответственно

# %%
fig.update_traces(marker_line_width=1, marker_line_color="white", texttemplate="%{y:.0f}", marker={'color': 'white'})  
fig.update_layout(margin=dict(l=0,r=0,b=0,t=5), showlegend=False, hoverlabel=dict(bgcolor="white"),xaxis_title="", yaxis_title="")

# %%
layout = dict(plot_bgcolor='white',
              margin=dict(t=20, l=20, r=20, b=20),
              xaxis=dict(title='World Rank',
                         range=[0.9, 5.5],
                         linecolor='#d9d9d9',
                         showgrid=False,
                         mirror=True),
              yaxis=dict(title='Citations',
                         range=[95.5, 99.5],
                         linecolor='#d9d9d9',
                         showgrid=False,
                         mirror=True))

data = go.Scatter(x=df['world_rank'],
                  y=df['citations'],
                  text=df['university_name'],
                  textposition='top right',
                  textfont=dict(color='#E58606'),
                  mode='lines+markers+text',
                  marker=dict(color='#5D69B1', size=8),
                  line=dict(color='#52BCA3', width=1, dash='dash'),
                  name='citations')

# %%
# pio.templates.default = "simple_white"
px.defaults.template = "simple_white"
px.defaults.color_continuous_scale = px.colors.sequential.Aggrnyl
px.defaults.color_discrete_sequence =  px.colors.qualitative.Bold
# можно задать цветовую последовательность самому  
px.defaults.color_discrete_sequence = ["rgba(243, 0, 0, 0.5)", "green", "#7FFF00", "goldenrod", "magenta"]
px.defaults.width = 500
px.defaults.height = 300

# %%
fig = px.line(x=["a","b","c"], y=[[1,3,2], [2,4,5], [3,4,6]], title="sample figure")
fig

# %%
fig = px.line(x=["a","b","c"], y=[1,3,2], title="sample figure")
print(fig)
fig.show()
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#1F77B4', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array(['a', 'b', 'c'], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 3, 2], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'height': 300,
#                'legend': {'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'sample figure'},
#                'width': 500,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %% [markdown]
# Менять параметры фигуры можно через обращение к конкретному свойству
# через точки, если не помнишь свойства, то можно посмотреть так
# или использую print
# Помним. что data это кортеж, поэтому, чтобы изменить какой-то
# trace, нужно его выбрать индексацией

# %%
fig.data[0]
# Out:
# Scatter({
#     'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#     'legendgroup': '',
#     'line': {'color': '#1F77B4', 'dash': 'solid'},
#     'marker': {'symbol': 'circle'},
#     'mode': 'lines',
#     'name': '',
#     'orientation': 'v',
#     'showlegend': True,
#     'x': array(['a', 'b', 'c'], dtype=object),
#     'xaxis': 'x',
#     'y': array([1, 3, 2], dtype=int64),
#     'yaxis': 'y'
# })

# %% [markdown]
# Чтобы изменить что-то, можно использовать словарь
# и метод update_layout или другой update
# можно как шаблон взять словарь из
# fig.layout

# %% [markdown]
# Обрезать метки по оси

# %%
fig = px.bar(dataa)
fig.update_layout(yaxis_title="Owners_Jurisdiction Count", xaxis_title="Owners")
fig.update_traces(x=[x[:7] for x in df['Owners_name']])
fig.update_xaxes(tickangle=45, showgrid=True)
fig.show()

# %%
fig.update_layout({
               'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x_test'}},
               'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y_test'}}})

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="sepal_length")
fig.update_layout(
    title_text='My title', # title of plot
    xaxis_title_text='my x axis title for x', # xaxis label
    yaxis_title_text='my x axis title for y', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig

# %%
df = px.data.tips()
fig = px.histogram(df, x="day", y="total_bill", color="sex")
fig.update_traces(overwrite=True, marker={"opacity": 0.4})
fig.show()

# %%
df = px.data.tips()
fig = px.histogram(df, x="day", y="total_bill", color="sex", barmode='overlay')
fig.show()

# %%
df = px.data.tips()
fig = px.histogram(df, x="day", y="total_bill", color="sex",
            title="Receipts by Payer Gender and Day of Week",
            width=600, height=400,
            labels={ # replaces default labels by column name
                "sex": "Payer Gender",  "day": "Day of Week", "total_bill": "Receipts"
            },
            category_orders={ # replaces default order by column name
                "day": ["Thur", "Fri", "Sat", "Sun"], "sex": ["Male", "Female"]
            },
            color_discrete_map={ # replaces default color mapping by value
                "Male": "RebeccaPurple", "Female": "MediumPurple"
            },
            template="simple_white"
            )
fig

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(df, x="day", y="total_bill", color="sex",
            title="Receipts by Payer Gender and Day of Week vs Target",
            width=600, height=400,
            labels={"sex": "Payer Gender",  "day": "Day of Week", "total_bill": "Receipts"},
            category_orders={"day": ["Thur", "Fri", "Sat", "Sun"], "sex": ["Male", "Female"]},
            color_discrete_map={"Male": "RebeccaPurple", "Female": "MediumPurple"},
            template="simple_white"
            )

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=True
)

fig.update_layout( # customize font and legend orientation & position
    legend=dict(
        title=None, orientation="h", y=1, yanchor="bottom", x=0.5, xanchor="center"
    ),
    title=dict(
        x=0.5
    ), 
    font=dict(
        family="Rockwell",
        size=12,
        color="RebeccaPurple"
    )
)

fig.add_shape( # add a horizontal "target" line
    type="line", line_color="salmon", line_width=3, opacity=1, line_dash="dot",
    x0=0, x1=1, xref="paper", y0=950, y1=950, yref="y"
)

fig.add_annotation( # add a text callout with arrow
    text="below target!", x="Fri", y=400, arrowhead=1, showarrow=True
)

fig.show()

# %%
df = px.data.iris()
fig = px.density_heatmap(df, x="sepal_width", y="sepal_length")
fig.show()

# %%
df = pd.DataFrame(dict(a=[1,3,2], b=[3,2,1]))
fig = df.plot(title="Pandas Backend Example", template="simple_white",
              labels=dict(index="time", value="money", variable="option"))
fig.update_yaxes(tickprefix="$")
fig.update_layout(
    title={
        'text': "Plot Title",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}
)
fig.show()

# %%
px.data.medals_long().head()
# Out:
#         nation   medal  count
# 0  South Korea    gold     24
# 1        China    gold     10
# 2       Canada    gold      9
# 3  South Korea  silver     13
# 4        China  silver     15

# %%
long_df = px.data.medals_long()

fig = px.bar(long_df, x="nation", y="count", color="medal", title="Long-Form Input")
fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color = "black"
fig.show()

# %%
px.data.medals_wide().head()
# Out:
#         nation  gold  silver  bronze
# 0  South Korea    24      13      11
# 1        China    10      15       8
# 2       Canada     9      12      12

# %%
wide_df = px.data.medals_wide()

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"], title="Wide-Form Input, relabelled",
            labels={"value": "count", "variable": "medal"})
fig.show()

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_length", y="sepal_width", color="species",
                title="Playing with Fonts")
fig.update_layout(
    font_family="Courier New",
    font_color="blue",
    title_font_family="Times New Roman",
    title_font_color="red",
    legend_title_font_color="green",
    title=dict(text="GDP-per-capita", font=dict(size=50), automargin=True, yref='paper')
)
fig.update_xaxes(title_font_family="Arial")
fig.show()

# %%
df = pd.DataFrame(dict(a=[1,3,2], b=[3,2,1]))

fig = df.plot.bar(facet_row="variable")
fig.show()

# %%
df = pd.DataFrame(dict(a=[1,3,2], b=[3,2,1]))

fig = df.plot.bar(facet_col="variable")
fig.show()

# %%
wide_df = px.data.medals_wide()

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"],
             title="Wide-Form Input, styled",
             labels={"value": "Medal Count", "variable": "Medal", "nation": "Olympic Nation"},
             color_discrete_map={"gold": "gold", "silver": "silver", "bronze": "#c96"},
             template="simple_white"
            )
fig.update_layout(font_family="Rockwell", showlegend=False)
fig.show()

# %%
wide_df = px.data.medals_wide()
wide_df = wide_df.set_index("nation")
wide_df.columns.name = "medals"
wide_df
# Out:
# medals       gold  silver  bronze
# nation
# South Korea    24      13      11
# China          10      15       8
# Canada          9      12      12

# %%
fig = px.bar(wide_df, x=wide_df.index, y=wide_df.columns)
fig.show()

# %%
wide_df = px.data.medals_wide(indexed=True)

fig = px.bar(wide_df, x=wide_df.columns, y=wide_df.index)
fig.show()

# %%
wide_df = px.data.medals_wide(indexed=False)

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"], facet_col="variable", color="nation")
fig.show()

# %%
wide_df = px.data.medals_wide(indexed=False)

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"], facet_col="variable", color=px.NO_COLOR)
fig.show()

# %%
df = px.data.gapminder().query("continent=='Oceania'")

fig = px.line(df, x="year", y="lifeExp", color="country", title="layout.hovermode='x'")
fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_layout(hovermode="x")

fig.show()

# %%
df = px.data.gapminder().query("continent=='Oceania'")

fig = px.line(df, x="year", y="lifeExp", color="country", title="layout.hovermode='x unified'")
fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_layout(hovermode="x unified")

fig.show()

# %%
mixed_df = px.data.experiment(indexed=True)

fig = px.violin(mixed_df, y=["experiment_1", "experiment_2", "experiment_3"], hover_data=[mixed_df.index])
fig.show()

# %%
mixed_df = px.data.experiment(indexed=True)

fig = px.violin(mixed_df, y=["experiment_1", "experiment_2", "experiment_3"],
                color="gender", facet_col="group", hover_data=[mixed_df.index])
fig.show()

# %%
mixed_df = px.data.experiment(indexed=True)

fig = px.violin(mixed_df, y=["experiment_1", "experiment_2", "experiment_3"],
                facet_row="gender", facet_col="group", hover_data=[mixed_df.index])
fig.show()

# %%
mixed_df = px.data.experiment(indexed=True)

fig = px.box(mixed_df, x="group", y=["experiment_1", "experiment_2", "experiment_3"],
                color="gender", facet_col="variable", hover_data=[mixed_df.index])
fig.show()

# %%
mixed_df = px.data.experiment(indexed=True)

fig = px.scatter_matrix(mixed_df, dimensions=["experiment_1", "experiment_2", "experiment_3"], color="gender")
fig.show()

# %%
fruits = ["apples", "oranges", "bananas"]
fig = px.line(x=fruits, y=[1,3,2], color=px.Constant("This year"),
             labels=dict(x="Fruit", y="Amount", color="Time Period"))
fig.add_bar(x=fruits, y=[2,1,3], name="Last year")
# fig.update_layout(showlegend=False)
fig.show()

# %% [markdown]
# Legend Positioning

# %%
df = px.data.gapminder().query("year==2007")
fig = px.scatter(df, x="gdpPercap", y="lifeExp", color="continent",
    size="pop", size_max=45, log_x=True)

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))

# %% [markdown]
# Continuous Color with Plotly Express
# For example, in the tips dataset, the size column contains numbers:

# %%
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", color="size",
                 title="Numeric 'size' values mean continuous color")
fig.show()

# %%
df = px.data.tips()
df["size"] = df["size"].astype(str)
fig = px.scatter(df, x="total_bill", y="tip", color="size",
                 title="String 'size' values mean discrete colors")

fig.show()

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 color="sepal_length", color_continuous_scale=px.colors.sequential.Viridis)

fig.show()

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="sepal_length",
                 color_continuous_scale=["red", "green", "blue"])

fig.show()

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="sepal_length",
                 color_continuous_scale=[(0, "red"), (0.5, "green"), (1, "blue")])

fig.show()

# %% [markdown]
# Можно указать четкие обе границы и тогда не будет плавного перехода,
# если нужно бар из трех цветов например

# %%
df = px.data.iris()
fig = px.parallel_coordinates(df, color="species_id",
                             color_continuous_scale=[(0.00, "red"),   (0.33, "red"),
                                                     (0.33, "green"), (0.66, "green"),
                                                     (0.66, "blue"),  (1.00, "blue")])
fig.show()

# %% [markdown]
# можно обрубить границы снизу и сверху,
# тогда ниже границы будут все одним нижним цветом

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="sepal_length", range_color=[5,8])

fig.show()

# %% [markdown]
# Можно скрыть калар бар

# %%
df = px.data.tips()
fig = px.density_heatmap(df, x="total_bill", y="tip", title="No color bar on this density plot")

fig.update_layout(coloraxis_showscale=False)

fig.show()

# %%
px.data.iris().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %%
df = px.data.iris()
fig = px.histogram(df, x="sepal_length", color="species", marginal="box")
fig.show()

# %%
df = px.data.gapminder().query("year == 2007")
fig = px.histogram(df, x="lifeExp", color="continent", marginal="rug", hover_name="country",
                  title="Hover over the rug plot!")
fig.show()

# %%
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", color="sex", facet_col="day",
                  marginal_x="box")
fig.show()

# %% [markdown]
# Plotly Express allows you to add Ordinary Least Squares regression trendline to scatterplots with the trendline argument.

# %%
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", trendline="ols")
fig.show()

# %%
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", symbol="smoker", color="sex", trendline="ols")
fig.show()

# %%
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", symbol="smoker", color="sex", trendline="ols", trendline_scope="overall", trendline_color_override="crimson")
fig.show()

# %%
df = px.data.medals_long()

fig = px.bar(df, x="medal", y="count", color="nation",
             pattern_shape="nation", pattern_shape_sequence=[".", "x", "+"])
fig.show()

# %%
df = px.data.tips()
fig = px.bar(df, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()

# %% [markdown]
# bar and histogram has same interface
# чтобы убрать полоски, просто испльзуем гистограму

# %%
df = px.data.tips()
fig = px.histogram(df, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()

# %%
df = px.data.tips()
fig = px.bar(df, x="sex", y="total_bill", color="smoker", barmode="group", facet_row="time", facet_col="day",
       category_orders={"day": ["Thur", "Fri", "Sat", "Sun"], "time": ["Lunch", "Dinner"]})
fig.show()

# %% [markdown]
# Animated figures with Plotly Express

# %%
px.data.gapminder().head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# animation_group это группирование в каждом кадре
# то есть если мы ставим группировать по стране
# то у нас в каждом кадре будет группировка по стране
# в бар чаре это не заметно, так как тут группировка итак по континенту и все,
# а вот в скэттер плоте, если поставить группировать по континенту, то будет одна точка на графике,
# мы каждый фрейм будем группировать все данные в одну точку

# %%
df = px.data.gapminder()

fig = px.bar(df, x="continent", y="pop", color="continent",
  animation_frame="year", animation_group="country", range_y=[0,4000000000], width=900, height=500)
fig.show()

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country", facet_col="continent",
           log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90], width=900, height=500)
fig.show()

# %% [markdown]
# если facet_col много значений, то можно использовать
# facet_col_wrap, чтобы разбить на строки

# %%
df = px.data.gapminder()
fig = px.scatter(df, x='gdpPercap', y='lifeExp', color='continent', size='pop',
                facet_col='year', facet_col_wrap=4)
fig.show()

# %%
df = px.data.tips()
fig = px.histogram(df, x="total_bill", y="tip", color="sex", facet_row="time", facet_col="day",
       category_orders={"day": ["Thur", "Fri", "Sat", "Sun"], "time": ["Lunch", "Dinner"]})
fig.show()

# %% [markdown]
# Adding Lines and Rectangles to Facet Plots

# %%
df = px.data.stocks(indexed=True)
fig = px.line(df, facet_col="company", facet_col_wrap=2, width=900, height=500)
fig.add_hline(y=1, line_dash="dot",
              annotation_text="Jan 1, 2018 baseline",
              annotation_position="bottom right")

fig.add_vrect(x0="2018-09-24", x1="2018-12-18", col=1,
              annotation_text="decline", annotation_position="top left",
              fillcolor="green", opacity=0.25, line_width=0)
fig.show()

# %%
df = px.data.gapminder().query("continent == 'Africa'")

fig = px.line(df, x="year", y="lifeExp", facet_col="country", facet_col_wrap=7,
              facet_row_spacing=0.04, # default is 0.07 when facet_col_wrap is used
              facet_col_spacing=0.04, # default is 0.03
              height=600, width=800,
              title="Life Expectancy in Africa")
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_yaxes(showticklabels=True)
fig.show()

# %%
df = pd.DataFrame( {
    "x" : [1,2,3,4,5,6,7,8],
    "y" : [-2, 3, -4, -1, -5, 5, 3, -3]
})
color = df['y'].apply(lambda x: 'green' if x >= 0 else 'crimson').values
fig = px.bar(df, x='x', y='y')    
fig.update_traces(marker_color=color)
fig

# %% [markdown]
# Strip chart

# %%
import plotly.express as px

df = px.data.tips()
fig = px.strip(df, x="total_bill", y="day")
fig.show()

# %%
import plotly.express as px

df = px.data.tips()
fig = px.strip(df, x="total_bill", y="time", color="sex")
fig.show()

# %%
import plotly.express as px

df = px.data.tips()
fig = px.strip(df, x="total_bill", y="time", color="sex", facet_col="day")
fig.show()

# %%
px.plotting_fn(dataframe, # Dataframe being visualized
               x=["column-for-x-axis"], # Accepts a string or a list of strings
               y=["columns-for-y-axis"], # Accepts a string or a list of strings
               title="Overall plot title", # Accepts a string
               xaxis_title="X-axis title", # Accepts a string
               yaxis_title="Y-axis title", # Accepts a string
               width=width_in_pixels, # Accepts an integer
               height=height_in_pixels) # Accepts an integer

# %%
# Create a scatterplot on a DataFrame named clinical_data
px.scatter(clinical_data, x="experiment_1", y="experiment_2")

# %%
# Create a lineplot on a DataFramed named stock_data
px.line(stock_data, x="date", y=["FB", "AMZN"])

# %%
# Create a barplot on a DataFramed named commodity_data
px.bar(commodity_data, x="nation", y=["gold", "silver", "bronze"],
       color_discrete_map={"gold": "yellow", 
                           "silver": "grey",
                           "bronze": "brown"})

# %%
# Create a histogram on a DataFramed named bill_data
px.histogram(bill_data, x="total_bill")

# %%
# Create a heatmap on a DataFramed named iris_data
px.imshow(iris_data.corr(numeric_only=True),
zmin=-1, zmax=1, color_continuous_scale='rdbu')

# %%
# In this example, we’re updating a scatter plot named fig_sct
fig_sct.update_traces(marker={ "size" : 24,
                           "color": "magenta",
                           "opacity": 0.5,
                           "line": {"width": 2, "color": "cyan"},
                           "symbol": "square"})
fig_sct.show()

# %% [markdown]
# Customizing lines in Plotly
# dash: set the dash style ("solid", "dot", "dash", "longdash", "dashdot", "longdashdot")
# shape: set how values are connected ("linear", "spline", "hv", "vh", "hvh","vhv")

# %%
# In this example, we’re updating a scatter plot named fig_ln
fig_ln.update_traces(patch={"line": {"dash": "dot",
                           "shape": "spline",
                           "width": 6}})
fig_ln.show()

# %%
# In this example, we’re updating a scatter plot named fig_bar
fig_bar.update_traces(marker={"color": "magenta",
                              "opacity": 0.5,
                              "line": {"width": 2, "color": "cyan"}})
fig_bar.show()
