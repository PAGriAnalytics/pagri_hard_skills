# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Подробно про subplots https://teletype.in/@pythontalk/matplotlib_subplot_tutorial
# rcparams https://matplotlib.org/stable/users/explain/customizing.html#the-default-matplotlibrc-file
#
# ### Table of Contents
# * [rcParams](#rcparams)
# * [plt.plot](#plot)
#     <!-- * [Section 1.1](#section_1_1)
#     * [Section 1.2](sSection_1_2)
#         * [Section 1.2.1](#section_1_2_1)
#         * [Section 1.2.2](#section_1_2_2)
#         * [Section 1.2.3](#section_1_2_3) -->
# <!-- * [Chapter 2](#chapter2)
#     * [Section 2.1](#section_2_1)
#     * [Section 2.2](#section_2_2) -->

# %% [markdown]
# ### Chapter 0 (rcParams) <a class="anchor" id="rcparams"></a>

# %%
import matplotlib
matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %%
# plt.rcParams['axes.spines.left'] = False
# plt.rcParams['axes.spines.right'] = False
# plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.spines.bottom'] = False
# plt.plot([1,2,3])
# plt.rcParams['ax']
plt.plot([1,2,3])

# %% [markdown]
# ### Chapter 1 (plot) <a class="anchor" id="plot"></a>

# %%
# with kwargs you can set various option
# they describe below in ?plt.plot
# ?plt.plot
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
plt.plot([1,2,3], [4,5,6], '--r')
plt.xticks(ticks=[0.5, 0.7], labels=['a', 'b'], rotation=50)
plt.xlabel('abc label')
plt.legend('line1')

# %%
plt.plot([1, 1, 2, 2, 1], [1, 2, 2, 1, 1])

# %%
x1 = [1,2,3]
y1 = [3,4,5]
x2 = [2,5,5]
y2 = [3,5,7]
plt.plot(x2, y2, 'go')
plt.plot(x1, y1, 'b^')

# %%
plt.plot([1,2,3], [1,2,3], ls='-', lw='2')
plt.plot([1,2,3], [5,6,7], ls='-.', lw='4')

# %%
lines = plt.plot(x1, y1, 'r-.o', x2, y2, 'g:*', [1,2,3], [5,6,7], '-b>')

# %%
# ?plt.setp
# Out:
# Signature: plt.setp(obj, *args, **kwargs)
# Docstring:
# Set one or more properties on an `.Artist`, or list allowed values.
#
# Parameters
# ----------
# obj : `.Artist` or list of `.Artist`
#     The artist(s) whose properties are being set or queried.  When setting
#     properties, all artists are affected; when querying the allowed values,
#     only the first instance in the sequence is queried.
#
#     For example, two lines can be made thicker and red with a single call:
#
#     >>> x = arange(0, 1, 0.01)
#     >>> lines = plot(x, sin(2*pi*x), x, sin(4*pi*x))
#     >>> setp(lines, linewidth=2, color='r')
#
# file : file-like, default: `sys.stdout`
#     Where `setp` writes its output when asked to list allowed values.
#
#     >>> with open('output.log') as file:
#     ...     setp(line, file=file)
#
#     The default, ``None``, means `sys.stdout`.
#
# *args, **kwargs
#     The properties to set.  The following combinations are supported:
#
# ...

# %%
lines = plt.plot(x1, y1, x2, y2, [1,2,3], [5,6,7])
plt.setp(lines[2], linewidth=2, color='b', linestyle='--', marker='o', markerfacecolor='r')
plt.grid()
plt.xlabel('x_lable')
plt.ylabel('y_lable', rotation=0)
plt.gca().yaxis.set_label_coords (-0.15, 0.5) 
plt.gca().xaxis.set_label_coords (0.3, -0.1) 
ax = plt.subplot()
ax.xaxis.set

# %%
plt.plot(x1, y1, c='#0000CC')

# plt.rcParams['axes.spines.left'] = False
# plt.rcParams['axes.spines.right'] = False
# plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.spines.bottom'] = False
plt.rcParams['ax']

# %%
plt.plot(x1, y1, c=(0,0,0), alpha=0.3)

# %% [markdown]
# Цвет можно задать через шестнадцатиричный код, тогда это будет строка начинающаяся с '#______'
# Либо можем указать кортеж с числами от 0 до 1 и это будет rgb
# И четвертым параметром можно указать прозрачность

# %%
plt.plot(x1, y1, c=(0.6, 0.6, 0.5, 0.3))

# %%
x = [1,2,3]
y = [4,5,6]
plt.plot(x, y)
plt.fill_between([1,2], 1)

# %%
x = [1,2,3]
y = [4,5,6]
plt.gcf().patch.set_facecolor((0.2,0.1,0.5))
plt.plot(x, y, zorder=0)
plt.title('title')
plt.xlabel('x', color='r')
plt.ylabel('y', color='b', rotation=0, loc='center')
plt.fill_between([1,2], 1)
ax = plt.gca()
ax.set_facecolor('cyan') # Темно-серый цвет: 0 – чёрный, 1 – белый
ax.spines["bottom"].set_color("green")      # x axis line
ax.spines["top"].set_color("purple")
ax.spines["left"].set_color("brown")        # y axis line
ax.tick_params(axis="x", colors="red")      # x tick labels
ax.tick_params(axis="y", colors="orange")   # y tick labels

# %%
import matplotlib.pyplot as plt
x_values1=[1,2,3,4,5]
y_values1=[1,2,2,4,1]
x_values2=[-1000,-800,-600,-400,-200]
y_values2=[10,20,39,40,50]
x_values3=[150,200,250,300,350]
y_values3=[-10,-20,-30,-40,-50]
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)
ax3=fig.add_subplot(111, label="3", frame_on=False)
ax.plot(x_values1, y_values1, color="C0")
ax.set_xlabel("x label 1", color="C0")
ax.set_ylabel("y label 1", color="C0")
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")
ax2.scatter(x_values2, y_values2, color="C1")
ax2.set_xlabel('x label 2', color="C1")
ax2.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
ax2.spines['bottom'].set_position(('outward', 36))
ax2.tick_params(axis='x', colors="C1")
ax2.set_ylabel('y label 2', color="C1")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position('right')
ax2.tick_params(axis='y', colors="C1")
ax3.plot(x_values3, y_values3, color="C2")
ax3.set_xlabel('x label 3', color='C2')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 72))
ax3.tick_params(axis='x', colors='C2')
ax3.set_ylabel('y label 3', color='C2')
ax3.yaxis.tick_right()
ax3.yaxis.set_label_position('right')
ax3.spines['right'].set_position(('outward', 36))
ax3.tick_params(axis='y', colors='C2')
plt.show()

# %%
import numpy as np
x = np.array([1,2,3,4,5,6])
y = np.array([4,5,6, 7, 8, 9])
plt.plot(x, y)
plt.title('title')
plt.xlabel('x', color='r')
plt.ylabel('y', color='b', rotation=0, loc='center')
plt.fill_between(x, y, 4, where=((y > 6) & (x > 4)), color='g')
plt.fill_between(x, y, 3, where=(y < 6), color='r')
plt.fill_between(x, y, 5, where=(y > 4) & ((x >= 2) & (x <= 5)), color='purple')

# %%
import matplotlib.image as img 
background = img.imread('background.jpg')
plt.imshow(background)
plt.axis('off')
# ax = plt.gca()
# plt.gcf().frameon = False
plt.gcf().patch.set_visible(False)

# %%
background = img.imread('background.jpg')
left = 1
right = 2
bottom = 1
top = 2
plt.imshow(background, zorder=0, extent=[left, right, bottom, top])
plt.plot([1,2,3])

# %%
background = img.imread('background.jpg')
left = -1
right = 2
bottom = 1
top = 2
plt.imshow(background, zorder=0, extent=[left, right, bottom, top])
plt.plot([1,2,3], color='r')
plt.gca().spines['bottom'].set_position(('outward', -70))

# %%
import numpy as np

# %%
c = np.random.randint(0, 50, 50)

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
rect = l, b, w, h
fig = plt.figure()
fig.add_axes(rect)
fig.add_axes(rect, frameon=False, facecolor='g')
fig.add_axes(rect, polar=True)
ax = fig.add_axes(rect, projection='polar')
fig.delaxes(ax)
fig.add_axes(ax)

# %%
image = plt.imread('background.jpg')
image_ratio = image.shape[0] / image.shape[1]
width = 10
fig, ax = plt.subplots(figsize=(width, width * image_ratio))
ax.patch.set_alpha(0.3)
background_ax = plt.axes([0, 0, 1, 1])
background_ax.set_zorder(-1)
background_ax.imshow(image)
background_ax.set_axis_off()
fig.patch.set_visible(False)
l = ax.plot([1,2,3], 'o', c='r')
ax.set_title('my title', color = 'w')
ax.set_xlabel('x lable', c='w', size=20)
ax.set_ylabel('y lable', c='w')
ax.xaxis.set_label_coords(0.6, -0.06)
ax.tick_params(axis='x', color='w')
ax.tick_params(axis='y', color='w')
ax.text(0.2, 2.75, r'$\mu=115,\ \sigma=15$', color='w')
ax.spines['left'].set_color('w')
ax.spines['bottom'].set_color('w')
ax.spines['right'].set_color('w')
ax.spines['top'].set_color('w')
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_color('w')
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_color('w')

# %%
fig, ax = plt.subplots(2,2)
ax = ax.flat
fig.patch.set_facecolor('xkcd:mint green')
# ax[0].patch.set_alpha(0.4)
ax[0].set_facecolor((0.5, 0.1, 0.2))
ax[1].set_facecolor((0,0.5,0))
ax[2].set_facecolor('b')
ax[3].set_facecolor('purple')
ax[0].spines["bottom"].set_color("green")      # x axis line
ax[0].spines["top"].set_color("purple")
ax[0].spines["left"].set_color("brown")        # y axis line
ax[0].tick_params(axis="x", colors="red")      # x tick labels
ax[0].tick_params(axis="y", colors="orange")  
plt.xlabel('ax 0 x lable')
plt.show()
